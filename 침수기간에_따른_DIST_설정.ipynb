# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 침수가 되어 있는 시간을 기준으로 DIST=1

# %%
F_Final_V2 = pd.read_excel('Reflux_data/Final_V2/F_Final_V2_test1.xlsx',index_col=False)
F_Final_V2.head()
# Out:
#        ADM_CD ZONE  Dong     SEQ DISTRICT  F_BEGIN_DE  F_END_DE  F_BEGIN_TM  \
# 0  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 1  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 2  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 3  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 4  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
#
#    F_END_TM  FLUD_TIME  ...  SLOPE_H  SLOPE_AVG  HIGH    PUMP_RATIO  \
# 0      1200         13  ...        2        1.0  1.57  1.189961e-07
# 1      1200         13  ...        2        1.0  1.57  1.189961e-07
# 2      1200         13  ...        2        1.0  1.57  1.189961e-07
# 3      1200         13  ...        2        1.0  1.57  1.189961e-07
# 4      1200         13  ...        2        1.0  1.57  1.189961e-07
#
#    IMP_SUR_RATIO  MANHOLES_RATIO  HOUR_RAINFALL  PRECI_YYMMDDHH  PRECI_HH  \
# ...

# %%
F_Final_V2=F_Final_V2_1.fillna(0)
F_Final_V2
# Out:
#           ADM_CD  ZONE  Dong     SEQ DISTRICT  F_BEGIN_DE  F_END_DE  \
# 0     2644010200   강서구  대저2동  102001    강동1지구    20190719  20190720
# 1     2644010200   강서구  대저2동  102001    강동1지구    20190719  20190720
# 2     2644010200   강서구  대저2동  102001    강동1지구    20190719  20190720
# 3     2644010200   강서구  대저2동  102001    강동1지구    20190719  20190720
# 4     2644010200   강서구  대저2동  102001    강동1지구    20190719  20190720
# ...          ...   ...   ...     ...      ...         ...       ...
# 3955  2635010600  해운대구    중동   30587     중동지구    20090716  20090716
# 3956  2635010600  해운대구    중동   30587     중동지구    20090716  20090716
# 3957  2635010600  해운대구    중동   30587     중동지구    20090716  20090716
# 3958  2635010600  해운대구    중동   30587     중동지구    20090716  20090716
# 3959  2635010600  해운대구    중동   30587     중동지구    20090716  20090716
#
#       F_BEGIN_TM  F_END_TM  FLUD_TIME  ...  SLOPE_H  SLOPE_AVG  HIGH  \
# 0           2300      1200         13  ...        2        1.0  1.57
# ...

# %%
F_Final_V2.to_excel("Reflux_data/Final_V2/F_Final_V2_test1.xlsx")

# %% [markdown]
# ## 비침수 데이터

# %%
Unf_Final_V2 = pd.read_excel('Reflux_data/Final_V2/Unf_Final_V2_test1.xlsx',index_col=False)
Unf_Final_V2.head()
# Out:
#        ADM_CD ZONE  Dong     SEQ DISTRICT  F_BEGIN_DE  F_END_DE  F_BEGIN_TM  \
# 0  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 1  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 2  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 3  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 4  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
#
#    F_END_TM  FLUD_TIME  ...  SLOPE_H  SLOPE_AVG  HIGH    PUMP_RATIO  \
# 0      1200         13  ...        2        1.0  1.57  1.189961e-07
# 1      1200         13  ...        2        1.0  1.57  1.189961e-07
# 2      1200         13  ...        2        1.0  1.57  1.189961e-07
# 3      1200         13  ...        2        1.0  1.57  1.189961e-07
# 4      1200         13  ...        2        1.0  1.57  1.189961e-07
#
#    IMP_SUR_RATIO  MANHOLES_RATIO  HOUR_RAINFALL  PRECI_YYMMDDHH  PRECI_HH  \
# ...

# %% [markdown]
# ## 행 병합

# %%
Final_V2_test1=pd.concat([F_Final_V2_1,Unf_Final_V2])
Final_V2_test1.head()
# Out:
#        ADM_CD ZONE  Dong     SEQ DISTRICT  F_BEGIN_DE  F_END_DE  F_BEGIN_TM  \
# 0  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 1  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 2  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 3  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
# 4  2644010200  강서구  대저2동  102001    강동1지구    20190719  20190720        2300
#
#    F_END_TM  FLUD_TIME  ...  SLOPE_H  SLOPE_AVG  HIGH    PUMP_RATIO  \
# 0      1200         13  ...        2        1.0  1.57  1.189961e-07
# 1      1200         13  ...        2        1.0  1.57  1.189961e-07
# 2      1200         13  ...        2        1.0  1.57  1.189961e-07
# 3      1200         13  ...        2        1.0  1.57  1.189961e-07
# 4      1200         13  ...        2        1.0  1.57  1.189961e-07
#
#    IMP_SUR_RATIO  MANHOLES_RATIO  HOUR_RAINFALL  PRECI_YYMMDDHH  PRECI_HH  \
# ...

# %%
Final_V2_test1.to_excel("Reflux_data/Final_V2/Final_V2_test1.xlsx")

# %% [markdown]
# ## 침수 되어 있는 데이터만 상관관계 분석

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data = F_Final_V2.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
plt.show()

# %% [markdown]
# ## 침수, 비침수 데이터를 합친 상관관계 분석

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data = Final_V2_test1.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
plt.show()
